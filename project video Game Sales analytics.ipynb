# %% [markdown]
# # Project on video game sales analytics

# %% [markdown]
# An application on univariate data analysis

# %%
# import requried libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading external dataset

# %%
df=pd.read_csv("D:\\DATA SCIENCE\\PROJECTS\\project on univariate data analysis\\Video_Games_Sales_analytics.csv")

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# ...

# %%
df.describe()
# Out:
#        Year_of_Release      NA_Sales      EU_Sales      JP_Sales  \
# count     16450.000000  16719.000000  16719.000000  16719.000000
# mean       2006.487356      0.263330      0.145025      0.077602
# std           5.878995      0.813514      0.503283      0.308818
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2020.000000     41.360000     28.960000     10.220000
#
#         Other_Sales  Global_Sales  Critic_Score  Critic_Count    User_Count
# count  16719.000000  16719.000000   8137.000000   8137.000000   7590.000000
# mean       0.047332      0.533543     68.967679     26.360821    162.229908
# std        0.186710      1.547935     13.938165     18.980495    561.282326
# min        0.000000      0.010000     13.000000      3.000000      4.000000
# ...

# %%
sns.distplot(df.Year_of_Release.dropna(), kde=False, bins = 39)
# Out:
# C:\Users\91846\AppData\Local\Temp\ipykernel_3044\958303305.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Year_of_Release.dropna(), kde=False, bins = 39)
# <Axes: xlabel='Year_of_Release'>

# %%
df.isna().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         6704
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
df.isna().mean().sort_values()
# Out:
# Platform           0.000000
# NA_Sales           0.000000
# EU_Sales           0.000000
# JP_Sales           0.000000
# Other_Sales        0.000000
# Global_Sales       0.000000
# Name               0.000120
# Genre              0.000120
# Publisher          0.003230
# Year_of_Release    0.016089
# Developer          0.396136
# User_Score         0.400981
# Rating             0.404869
# Critic_Score       0.513308
# Critic_Count       0.513308
# User_Count         0.546025
# dtype: float64

# %%
df.columns
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating'],
#       dtype='object')

# %%
import missingno as mn
mn.matrix(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 2
#       1 import missingno as mn
# ----> 2 mn.matrix(df)
#
# File ~\anaconda3\Lib\site-packages\missingno\missingno.py:65, in matrix(df, filter, n, p, sort, figsize, width_ratios, color, fontsize, labels, sparkline, inline, freq)
#      63 # Remove extraneous default visual elements.
#      64 ax0.set_aspect('auto')
# ---> 65 ax0.grid(b=False)
#      66 ax0.xaxis.tick_top()
#      67 ax0.xaxis.set_ticks_position('none')
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:3196, in _AxesBase.grid(self, visible, which, axis, **kwargs)
#    3194 _api.check_in_list(['x', 'y', 'both'], axis=axis)
#    3195 if axis in ['x', 'both']:
# -> 3196     self.xaxis.grid(visible, which=which, **kwargs)
#    3197 if axis in ['y', 'both']:
#    3198     self.yaxis.grid(visible, which=which, **kwargs)
#
# ...

# %%
sns.distplot(df.Year_of_Release)
# Out:
# C:\Users\91846\AppData\Local\Temp\ipykernel_3044\3299294934.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Year_of_Release)
# <Axes: xlabel='Year_of_Release', ylabel='Density'>

# %%
sns.distplot(df.Critic_Count,kde=False)
# Out:
# C:\Users\91846\AppData\Local\Temp\ipykernel_3044\2541731336.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Critic_Count,kde=False)
# <Axes: xlabel='Critic_Count'>

# %%
sns.distplot(df.JP_Sales)
# Out:
# C:\Users\91846\AppData\Local\Temp\ipykernel_3044\1090836677.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.JP_Sales)
# <Axes: xlabel='JP_Sales', ylabel='Density'>

# %%
sns.boxplot(df.Year_of_Release.dropna())
# Out:
# <Axes: ylabel='Year_of_Release'>

# %%
sns.boxplot(df.Year_of_Release.dropna())
# Out:
# <Axes: ylabel='Year_of_Release'>

# %%
sns.boxplot(df.Critic_Score,color='green')
# Out:
# <Axes: ylabel='Critic_Score'>

# %%
df['Critic_Score'].mean()
# Out:
# 68.96767850559173

# %%
df['Critic_Score'].median()
# Out:
# 71.0

# %%
df['Critic_Score'].mode()
# Out:
# 0    70.0
# Name: Critic_Score, dtype: float64

# %%
sns.histplot(df.Critic_Score,color="red",kde=True)
# Out:
# <Axes: xlabel='Critic_Score', ylabel='Count'>

# %%
sns.scatterplot(data=df,x=df.index,y=df['Year_of_Release'])
# Out:
# <Axes: xlabel='None', ylabel='Year_of_Release'>

# %%
sns.scatterplot(data=df,x=df.index,y='JP_Sales')
# Out:
# <Axes: xlabel='None', ylabel='JP_Sales'>

# %%
sns.lineplot(data=df,x=df.index,y='Critic_Score',hue=df['Year_of_Release'])
# Out:
# <Axes: xlabel='None', ylabel='Critic_Score'>

# %%
sns.stripplot(x=df['User_Count'],color='green')
# Out:
# <Axes: xlabel='User_Count'>

# %%
sns.boxplot(data=df, x="Critic_Count", y="Rating")
# Out:
# <Axes: xlabel='Critic_Count', ylabel='Rating'>

# %%
sns.swarmplot(x=df['Critic_Count'])
# Out:
# C:\Users\91846\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 9.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='Critic_Count'>
# C:\Users\91846\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 79.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# Error in callback <function flush_figures at 0x00000228686DA3E0> (for post_execute), with arguments args (),kwargs {}:
# KeyboardInterrupt

# %%
df['Year_of_Release'].value_counts().head(10).plot.bar()
# Out:
# <Axes: xlabel='Year_of_Release'>
