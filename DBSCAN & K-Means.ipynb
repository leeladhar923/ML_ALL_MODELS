# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN

from sklearn.preprocessing import StandardScaler
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\91846\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\91846\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\91846\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
#     self.io_loop.start()
# ...

# %%
#read the data
blobs = pd.read_csv("D:\DATA_SCIENCE\ALGORITHMS\MACHINE_LEARNING_ALGORITHMS\DBscan&k-means\cluster_blobs.csv")
moons = pd.read_csv("D:\DATA_SCIENCE\ALGORITHMS\MACHINE_LEARNING_ALGORITHMS\DBscan&k-means\cluster_moons.csv")
circles = pd.read_csv("D:\DATA_SCIENCE\ALGORITHMS\MACHINE_LEARNING_ALGORITHMS\DBscan&k-means\cluster_circles.csv")

# %%
#Visalize the 3 datasets
#scatter plot
plt.figure(figsize = (8,4), dpi = 100)
sns.scatterplot(data=blobs,x='X1',y='X2')
plt.show()

# %%
#scatter plot
plt.figure(figsize = (8,4), dpi = 100)
sns.scatterplot(data=moons,x='X_1',y='X_2')
plt.show()

# %%
#scatter plot
plt.figure(figsize = (8,4), dpi = 100)
sns.scatterplot(data=circles,x='X1',y='X2')
plt.show()

# %%
#Label Discovery Function
#rename moons columns 
moons.rename({"X_1": 'X1', 'X_2': 'X2'}, axis = 1, inplace = True)

# %%
#define the function 
def display_categories(model,data):
    labels = model.fit_predict(data)
    plt.figure(figsize = (8,4), dpi = 100)
    sns.scatterplot(data=data,x='X1',y='X2',hue=labels,palette='Set1')
    plt.show()

# %%
#Kmeans Results
#intiate the model
model = KMeans(n_clusters = 2)
display_categories(model,moons)

# %%
#intiate the model
model = KMeans(n_clusters = 3)
display_categories(model,blobs)

# %%
#intiate the model
model = KMeans(n_clusters = 2)
display_categories(model,circles)

# %% [markdown]
# We clearly see that because K-Means is distance based algorithms, it is unable to capture complex relationships between features.

# %%
#DBSCAN Results
#intiate the model
model = DBSCAN(eps=0.6)
display_categories(model,blobs)

# %%
#intiate the model
model = DBSCAN(eps=0.15)
display_categories(model,moons)

# %%
#intiate the model
model = DBSCAN(eps=0.15)
display_categories(model,circles)

# %% [markdown]
# However, one might think that these points are not outliers, here we should change the default parameters of DBSCAN to take that into account. The parameter that is responsible for that called "epsilon" which deside the range of which n pints is to be considered as neighbors.

# %%
#Hyperparameter tuning
# lets read another dataframe
two_blobs = pd.read_csv("D:\DATA SCIENCE\ALGORITHMS\MACHINE LEARNING ALGORITHMS\DBscan & k-means\cluster_two_blobs.csv")
two_blobs_outliers = pd.read_csv("D:\DATA SCIENCE\ALGORITHMS\MACHINE LEARNING ALGORITHMS\DBscan & k-means\cluster_two_blobs_outliers.csv")

# %%
#scatter plot
plt.figure(figsize = (8,4), dpi = 100)
sns.scatterplot(data=two_blobs,x='X1',y='X2')
plt.show()

# %%
#scatter plot
plt.figure(figsize = (8,4), dpi = 100)
sns.scatterplot(data=two_blobs_outliers,x='X1',y='X2')
plt.show()

# %%
#the model
dbscan = DBSCAN()
display_categories(dbscan,two_blobs)

# %%
#the model
display_categories(dbscan,two_blobs_outliers)

# %% [markdown]
# We need to adjust epsilon to make the algorithm understand that the 3 red dots near the green cluster are not actually outliers

# %%
#understanding the effect of changing epsilon 
dbscan = DBSCAN(eps = 0.001) #the default 0.5 
display_categories(dbscan,two_blobs_outliers)

# %%
#understanding the effect of changing epsilon 
dbscan = DBSCAN(eps = 10) #the default 0.5 
display_categories(dbscan,two_blobs_outliers)

# %%
#understanding the effect of changing epsilon 
dbscan = DBSCAN(eps = 1) #the default 0.5 
display_categories(dbscan,two_blobs_outliers)

# %% [markdown]
# Setting Epsilon = 1 gives us the desired outcome as shown in the above graph

# %%
# the number of outliers
np.sum(dbscan.labels_ == -1)
# Out:
# 3

# %%
# the percent of outliers
100 * np.sum(dbscan.labels_ == -1) / len(dbscan.labels_)
# Out:
# 0.29910269192422734

# %%
#Create an Elbo values 
outlier_percent = []
number_of_outliers = []

for eps in np.linspace(0.001,10,100):
    
    # Create Model
    dbscan = DBSCAN(eps=eps)
    dbscan.fit(two_blobs_outliers)
    
    # Log Number of Outliers
    number_of_outliers.append(np.sum(dbscan.labels_ == -1))
    
    # Log percentage of points that are outliers
    perc_outliers = 100 * np.sum(dbscan.labels_ == -1) / len(dbscan.labels_)
    
    outlier_percent.append(perc_outliers)

# %%
#create the Elbo Graph 
plt.figure(figsize = (8,4), dpi = 100)
sns.lineplot(x=np.linspace(0.001,10,100),y=number_of_outliers)
plt.ylabel("Percentage of Points Classified as Outliers")
plt.xlabel("Epsilon Value")
# Out:
# Text(0.5, 0, 'Epsilon Value')

# %% [markdown]
# We are interested in reflection points where we go from extreme number of outliers to some extreme number of no outliers

# %%
#create the Elbo Graph 
plt.figure(figsize = (8,4), dpi = 100)
sns.lineplot(x=np.linspace(0.001,10,100),y=number_of_outliers)

#X, Y limits
plt.xlim(0,2)
plt.ylim(0,50)

#H-Line 
plt.hlines(y=3,xmin=0,xmax=2,colors='red',ls='--')

#labels 
plt.ylabel("Percentage of Points Classified as Outliers")
plt.xlabel("Epsilon Value")
# Out:
# Text(0.5, 0, 'Epsilon Value')

# %% [markdown]
# We know that we have 3 outliers in our dataset, so we set a h-line on 3 and we figured out the corresponding value of Epsilon that gives us this particular number of outliers is some where around 0.75 - In general we are searching for this turning point. May be for example you are interested for 1 percent of points as outliers, you can definitely play with that.

# %%
#read the data
df = pd.read_csv("D:\DATA SCIENCE\ALGORITHMS\MACHINE LEARNING ALGORITHMS\DBscan & k-means\wholesome_customers_data.csv")

# %%
#top 5 rows 
df.head()
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338
# 1        2       3   7057  9810     9568    1762              3293        1776
# 2        2       3   6353  8808     7684    2405              3516        7844
# 3        1       3  13265  1196     4221    6404               507        1788
# 4        2       3  22615  5410     7198    3915              1777        5185

# %%
#EDA
plt.figure(figsize = (8,4), dpi = 100)
sns.scatterplot(data=df,x='Milk',y='Grocery',hue='Channel')
plt.show()

# %%
#EDA
plt.figure(figsize = (8,4), dpi = 100)
sns.histplot(df,x='Milk',hue='Channel',multiple="stack")
plt.show()

# %%
#an annotated clustermap of the correlations between spending on different cateogires.
print('Correlation Between Spending Categories')
sns.clustermap(df.drop(['Region','Channel'],axis=1).corr(),annot=True);
# Out:
# Correlation Between Spending Categories

# %%
#PairPlot of the dataframe, colored by Region.
sns.pairplot(df,hue='Region',palette='Set1')

# %%
#Scale the data 
scaler = StandardScaler()
scaled_X = scaler.fit_transform(df)

# %% [markdown]
# Using DBSCAN and a for loop to create a variety of models testing different epsilon values. Set min_samples equal to 2 times the number of features. During the loop, keep track of and log the percentage of points that are outliers. For reference the solutions notebooks uses the following range of epsilon values for testing:

# %%
outlier_percent = []

for eps in np.linspace(0.001,3,50):
    
    # Create Model
    dbscan = DBSCAN(eps=eps,min_samples=2*scaled_X.shape[1])
    dbscan.fit(scaled_X)
   
     
    # Log percentage of points that are outliers
    perc_outliers = 100 * np.sum(dbscan.labels_ == -1) / len(dbscan.labels_)
    
    outlier_percent.append(perc_outliers)

# %%
#a line plot of the percentage of outlier points versus the epsilon value choice.
plt.figure(figsize = (8,4), dpi = 100)
sns.lineplot(x=np.linspace(0.001,3,50),y=outlier_percent)
plt.ylabel("Percentage of Points Classified as Outliers")
plt.xlabel("Epsilon Value")
plt.show()

# %% [markdown]
# Based on the plot created in the previous task, retrain a DBSCAN model with a reasonable epsilon value. Note: For reference, the solutions use eps=2.

# %%
#fit DBSCAN with eps = 2
dbscan = DBSCAN(eps=2)
dbscan.fit(scaled_X)
# Out:
# DBSCAN(eps=2)

# %%
# plot the result 
plt.figure(figsize = (8,4), dpi = 100)
sns.scatterplot(data=df,x='Grocery',y='Milk',hue=dbscan.labels_)
plt.show()

# %%
# plot the result 
plt.figure(figsize = (8,4), dpi = 100)
sns.scatterplot(data=df,x='Detergents_Paper',y='Milk',hue=dbscan.labels_)
plt.show()

# %% [markdown]
# Create a new column on the original dataframe called "Labels" consisting of the DBSCAN labels.

# %%
#Create a new column on the original dataframe called "Labels" consisting of the DBSCAN labels.
df['Labels'] = dbscan.labels_

# %%
#Compare the statistical mean of the clusters and outliers for the spending amounts on the categories.
cats = df.drop(['Channel','Region'],axis=1)
cats.groupby('Labels').mean()
# Out:
#                Fresh          Milk       Grocery        Frozen  \
# Labels
# -1      30161.529412  26872.411765  33575.823529  12380.235294
#  0       8200.681818   8849.446970  13919.113636   1527.174242
#  1      12662.869416   3180.065292   3747.250859   3228.862543
#
#         Detergents_Paper   Delicassen
# Labels
# -1          14612.294118  8185.411765
#  0           6037.280303  1548.310606
#  1            764.697595  1125.134021

# %% [markdown]
# We can see that the outliers have the most extreme spending values. The algorithm did a very good job with detecting these outliers.
