# %% [markdown]
# ## Computing the Spearman's rank correlation coefficient using pandas

# %%
import numpy as np
import pandas as pd
import seaborn as sns#for pairplots and heatmaps
import matplotlib.pyplot as plt

# %%
x_simple=pd.DataFrame([(-2,4),(-1,1),(0,3),(1,2),(2,0)],columns=['X','Y'])
my_r = x_simple.corr(method="spearman")
print(my_r)
# Out:
#      X    Y
# X  1.0 -0.7
# Y -0.7  1.0

# %%
def display_correlation(df):
    r=df.corr(method='spearman')
    plt.figure(figsize=(10,6))
    heatmap=sns.heatmap(df.corr(),vmin=1,vmax=1,annot=True)
    plt.title('spearman correlation')
    return(r)

# %%
r_simple=display_correlation(x_simple)

# %% [markdown]
# ## pearson correlation

# %%
x_simple=pd.DataFrame([(-2,4),(-1,1),(0,3),(1,2),(2,0)],columns=['X','Y'])
my_r = x_simple.corr(method="pearson")
print(my_r)
# Out:
#      X    Y
# X  1.0 -0.7
# Y -0.7  1.0
